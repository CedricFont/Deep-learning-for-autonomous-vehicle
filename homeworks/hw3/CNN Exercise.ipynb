# %% [markdown]
# ## Convolutional Networks
#
# We'll check out how to build a **convolutional network** to classify CIFAR10 images. By using weight sharing - multiple units with the same weights - convolutional layers are able to learn repeated patterns in your data. For example, a unit could learn the pattern for an eye, or a face, or lower level features like edges.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import time

import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
import torch.utils.data as utils
from torchvision import datasets, transforms
from torch.utils.data.sampler import SubsetRandomSampler
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
label_names = [
    'airplane',
    'automobile',
    'bird',
    'cat',
    'deer',
    'dog',
    'frog',
    'horse',
    'ship',
    'truck'
]


def plot_images(images, cls_true, cls_pred=None):
    """
    Adapted from https://github.com/Hvass-Labs/TensorFlow-Tutorials/
    """
    fig, axes = plt.subplots(3, 3)

    for i, ax in enumerate(axes.flat):
        # plot img
        ax.imshow(images[i, :, :, :], interpolation='spline16')

        # show true & predicted classes
        cls_true_name = label_names[cls_true[i]]
        if cls_pred is None:
            xlabel = "{0} ({1})".format(cls_true_name, cls_true[i])
        else:
            cls_pred_name = label_names[cls_pred[i]]
            xlabel = "True: {0}\nPred: {1}".format(
                cls_true_name, cls_pred_name
            )
        ax.set_xlabel(xlabel)
        ax.set_xticks([])
        ax.set_yticks([])

    plt.show()

# %%
def get_train_valid_loader(data_dir='data',
                           batch_size=64,
                           augment=False,
                           random_seed = 1,
                           valid_size=0.02,
                           shuffle=True,
                           show_sample=True,
                           num_workers=4,
                           pin_memory=False):
    """
    Utility function for loading and returning train and valid
    multi-process iterators over the CIFAR-10 dataset. A sample
    9x9 grid of the images can be optionally displayed.
    If using CUDA, num_workers should be set to 1 and pin_memory to True.
    Params
    ------
    - data_dir: path directory to the dataset.
    - batch_size: how many samples per batch to load.
    - augment: whether to apply the data augmentation scheme
      mentioned in the paper. Only applied on the train split.
    - random_seed: fix seed for reproducibility.
    - valid_size: percentage split of the training set used for
      the validation set. Should be a float in the range [0, 1].
    - shuffle: whether to shuffle the train/validation indices.
    - show_sample: plot 9x9 sample grid of the dataset.
    - num_workers: number of subprocesses to use when loading the dataset.
    - pin_memory: whether to copy tensors into CUDA pinned memory. Set it to
      True if using GPU.
    Returns
    -------
    - train_loader: training set iterator.
    - valid_loader: validation set iterator.
    """
    error_msg = "[!] valid_size should be in the range [0, 1]."
    assert ((valid_size >= 0) and (valid_size <= 1)), error_msg

    normalize = transforms.Normalize(
        mean=[0.4914, 0.4822, 0.4465],
        std=[0.2023, 0.1994, 0.2010],
    )

    # define transforms
    valid_transform = transforms.Compose([
            transforms.ToTensor(),
            normalize,
    ])
    if augment:
        train_transform = transforms.Compose([
            transforms.RandomCrop(32, padding=4),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            normalize,
        ])
    else:
        train_transform = transforms.Compose([
            transforms.ToTensor(),
            normalize,
        ])

    # load the dataset
    train_dataset = datasets.CIFAR10(
        root=data_dir, train=True,
        download=True, transform=train_transform,
    )

    valid_dataset = datasets.CIFAR10(
        root=data_dir, train=True,
        download=True, transform=valid_transform,
    )

    num_train = len(train_dataset)
    indices = list(range(num_train))
    split = int(np.floor(valid_size * num_train))

    if shuffle:
        np.random.seed(random_seed)
        np.random.shuffle(indices)

    train_idx, valid_idx = indices[split:], indices[:split]
    train_sampler = SubsetRandomSampler(train_idx)
    valid_sampler = SubsetRandomSampler(valid_idx)

    train_loader = torch.utils.data.DataLoader(
        train_dataset, batch_size=batch_size, sampler=train_sampler,
        num_workers=num_workers, pin_memory=pin_memory,
    )
    valid_loader = torch.utils.data.DataLoader(
        valid_dataset, batch_size=batch_size, sampler=valid_sampler,
        num_workers=num_workers, pin_memory=pin_memory,
    )

    # visualize some images
    if show_sample:
        sample_loader = torch.utils.data.DataLoader(
            train_dataset, batch_size=9, shuffle=shuffle,
            num_workers=num_workers, pin_memory=pin_memory,
        )
        data_iter = iter(sample_loader)
        images, labels = data_iter.next()
        X = images.numpy().transpose([0, 2, 3, 1])
        plot_images(X, labels)

    return (train_loader, valid_loader)

trainloader, valloader = get_train_valid_loader()
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to data/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting data/cifar-10-python.tar.gz to data
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
trainloader.next()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-b627eb97323d> in <module>()
# ----> 1 trainloader.next()
#
# AttributeError: 'DataLoader' object has no attribute 'next'

# %%
class ConvNet(nn.Module):
    def __init__(self, n_input_channels=3, n_output=10):
        super().__init__()
        ################################################################################
        # TODO:                                                                        #
        # Define 2 or more different layers of the neural network                      #
        ################################################################################
        
        self.feature_extractor = torch.nn.Sequential(
            
          torch.nn.Conv2d(3, 20, kernel_size=(5,5)),
          torch.nn.BatchNorm2d(20),
          torch.nn.ReLU(inplace=True),
          torch.nn.MaxPool2d(kernel_size=(2,2), stride=2),

          torch.nn.Conv2d(20, 20, kernel_size=(4,4)),
          torch.nn.BatchNorm2d(20),
          torch.nn.ReLU(inplace=True),
          torch.nn.MaxPool2d(kernel_size=(2,2))

        )

        self.classifier = torch.nn.Sequential(
            
          torch.nn.Linear(20 * 5 * 5, 10)

        )

        ################################################################################
        #                              END OF YOUR CODE                                #
        ################################################################################
    
    def forward(self, x):
        ################################################################################
        # TODO:                                                                        #
        # Set up the forward pass that the input data will go through.                 #
        # A good activation function betweent the layers is a ReLu function.           #
        #                                                                              #
        # Note that the output of the last convolution layer should be flattened       #
        # before being inputted to the fully connected layer. We can flatten           #
        # Tensor `x` with `x.view`.                                                    #
        ################################################################################

        x = self.feature_extractor(x)
        print(x.size())
        x = x.view(x.size(0), -1)
        # print(x.size())
        x = self.classifier(x)

        ################################################################################
        #                              END OF YOUR CODE                                #
        ################################################################################
        
        return x
    
    def predict(self, x):
        logits = self.forward(x)
        return F.softmax(logits)

# %%
net = ConvNet()
################################################################################
# TODO:                                                                        #
# Choose an Optimizer that will be used to minimize the loss function.         #
# Choose a critera that measures the loss                                      #
################################################################################
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(net.parameters(), lr=1e-4)

epochs = 10
lrs = np.logspace(-3,-7,epochs)
steps = 0
running_loss = 0
print_every = 20
for e in range(epochs):
    start = time.time()
    for images, labels in iter(trainloader):
        
        steps += 1
        ################################################################################
        # TODO:                                                                        #
        # Run the training process                                                     #
        #                                                                              #
        #                                                                              #
        ################################################################################

        optimizer.param_groups[0]['lr'] = lrs[e]
        optimizer.zero_grad()
        output = net(images)

        ################################################################################
        #                              END OF YOUR CODE                                #
        ################################################################################
        
        loss = criterion(output, labels)
        ################################################################################
        # TODO:                                                                        #
        # Run the training process                                                     #
        #                                                                              #
        # HINT: Calculate the gradient and move one step further                       #
        ################################################################################
        
        loss.backward()
        optimizer.step()

        ################################################################################
        #                              END OF YOUR CODE                                #
        ################################################################################
        
        running_loss += loss.item()
        
        if steps % print_every == 0:
            stop = time.time()
            # Test accuracy
            accuracy = 0
            for ii, (images, labels) in enumerate(valloader):
                
                ################################################################################
                # TODO:                                                                        #
                # Calculate the accuracy                                                       #
                ################################################################################
                
                pred_val = net(images)
                running_loss = criterion(pred_val, labels)

                # print(torch.argmax(pred_val,dim=1).size())
                accuracy += (torch.argmax(pred_val,dim=1) == labels).sum() / labels.size(0)

                ################################################################################
                #                              END OF YOUR CODE                                #
                ################################################################################
            
            print("Epoch: {}/{}..".format(e+1, epochs),
                  "Loss: {:.4f}..".format(running_loss/print_every),
                  "Test accuracy: {:.4f}..".format(accuracy/(ii+1)),
                  "{:.4f} s/batch".format((stop - start)/print_every),
                  "Learning rate : {:,4f}..".format(optimizer.param_groups[0]['lr'])
                 )
            running_loss = 0
            start = time.time()
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch: 1/10.. Loss: 0.1202.. Test accuracy: 0.2477.. 0.0876 s/batch
# Epoch: 1/10.. Loss: 0.0913.. Test accuracy: 0.3313.. 0.0643 s/batch
# Epoch: 1/10.. Loss: 0.0851.. Test accuracy: 0.3566.. 0.0653 s/batch
# Epoch: 1/10.. Loss: 0.0867.. Test accuracy: 0.3949.. 0.0639 s/batch
# Epoch: 1/10.. Loss: 0.0843.. Test accuracy: 0.4047.. 0.0629 s/batch
# Epoch: 1/10.. Loss: 0.0918.. Test accuracy: 0.3889.. 0.0599 s/batch
# Epoch: 1/10.. Loss: 0.0750.. Test accuracy: 0.4328.. 0.0631 s/batch
# Epoch: 1/10.. Loss: 0.0711.. Test accuracy: 0.4459.. 0.0587 s/batch
# Epoch: 1/10.. Loss: 0.0773.. Test accuracy: 0.4592.. 0.0661 s/batch
# Epoch: 1/10.. Loss: 0.0680.. Test accuracy: 0.4555.. 0.0655 s/batch
# Epoch: 1/10.. Loss: 0.0749.. Test accuracy: 0.4525.. 0.0601 s/batch
# Epoch: 1/10.. Loss: 0.0841.. Test accuracy: 0.4754.. 0.0663 s/batch
# Epoch: 1/10.. Loss: 0.0775.. Test accuracy: 0.4697.. 0.0732 s/batch
# Epoch: 1/10.. Loss: 0.0728.. Test accuracy: 0.5055.. 0.0697 s/batch
# Epoch: 1/10.. Loss: 0.0696.. Test accuracy: 0.4811.. 0.0622 s/batch
# Epoch: 1/10.. Loss: 0.0629.. Test accuracy: 0.4975.. 0.0613 s/batch
# Epoch: 1/10.. Loss: 0.0825.. Test accuracy: 0.4945.. 0.0607 s/batch
# Epoch: 1/10.. Loss: 0.0611.. Test accuracy: 0.5117.. 0.0960 s/batch
# Epoch: 1/10.. Loss: 0.0689.. Test accuracy: 0.5203.. 0.1254 s/batch
# Epoch: 1/10.. Loss: 0.0774.. Test accuracy: 0.5336.. 0.0932 s/batch
# Epoch: 1/10.. Loss: 0.0718.. Test accuracy: 0.5311.. 0.0922 s/batch
# Epoch: 1/10.. Loss: 0.0691.. Test accuracy: 0.5176.. 0.0602 s/batch
# Epoch: 1/10.. Loss: 0.0640.. Test accuracy: 0.5279.. 0.0605 s/batch
# Epoch: 1/10.. Loss: 0.0847.. Test accuracy: 0.5094.. 0.0565 s/batch
# Epoch: 1/10.. Loss: 0.0749.. Test accuracy: 0.5318.. 0.0640 s/batch
# Epoch: 1/10.. Loss: 0.0639.. Test accuracy: 0.5461.. 0.0607 s/batch
# Epoch: 1/10.. Loss: 0.0667.. Test accuracy: 0.5598.. 0.0642 s/batch
# Epoch: 1/10.. Loss: 0.0572.. Test accuracy: 0.5508.. 0.0603 s/batch
# Epoch: 1/10.. Loss: 0.0758.. Test accuracy: 0.5322.. 0.0640 s/batch
# Epoch: 1/10.. Loss: 0.0635.. Test accuracy: 0.5703.. 0.0621 s/batch
# Epoch: 1/10.. Loss: 0.0743.. Test accuracy: 0.5375.. 0.0646 s/batch
# Epoch: 1/10.. Loss: 0.0710.. Test accuracy: 0.5488.. 0.0587 s/batch
# Epoch: 1/10.. Loss: 0.0640.. Test accuracy: 0.5383.. 0.0779 s/batch
# Epoch: 1/10.. Loss: 0.0472.. Test accuracy: 0.5535.. 0.0656 s/batch
# Epoch: 1/10.. Loss: 0.0601.. Test accuracy: 0.5691.. 0.1168 s/batch
# Epoch: 1/10.. Loss: 0.0635.. Test accuracy: 0.5344.. 0.0919 s/batch
# Epoch: 1/10.. Loss: 0.0780.. Test accuracy: 0.5355.. 0.0800 s/batch
# Epoch: 1/10.. Loss: 0.0636.. Test accuracy: 0.5473.. 0.0613 s/batch
# Epoch: 2/10.. Loss: 0.0609.. Test accuracy: 0.5416.. 0.0613 s/batch
# Epoch: 2/10.. Loss: 0.0384.. Test accuracy: 0.5967.. 0.0576 s/batch
# Epoch: 2/10.. Loss: 0.0716.. Test accuracy: 0.5920.. 0.0606 s/batch
# Epoch: 2/10.. Loss: 0.0680.. Test accuracy: 0.5953.. 0.0601 s/batch
# Epoch: 2/10.. Loss: 0.0588.. Test accuracy: 0.5816.. 0.0663 s/batch
# Epoch: 2/10.. Loss: 0.0600.. Test accuracy: 0.5928.. 0.0735 s/batch
# Epoch: 2/10.. Loss: 0.0610.. Test accuracy: 0.5809.. 0.0639 s/batch
# Epoch: 2/10.. Loss: 0.0642.. Test accuracy: 0.5848.. 0.0636 s/batch
# Epoch: 2/10.. Loss: 0.0505.. Test accuracy: 0.5877.. 0.0594 s/batch
# Epoch: 2/10.. Loss: 0.0735.. Test accuracy: 0.5795.. 0.0647 s/batch
# Epoch: 2/10.. Loss: 0.0657.. Test accuracy: 0.5809.. 0.0577 s/batch
# Epoch: 2/10.. Loss: 0.0664.. Test accuracy: 0.5951.. 0.0636 s/batch
# Epoch: 2/10.. Loss: 0.0578.. Test accuracy: 0.5895.. 0.0678 s/batch
# Epoch: 2/10.. Loss: 0.0631.. Test accuracy: 0.5939.. 0.0662 s/batch
# Epoch: 2/10.. Loss: 0.0539.. Test accuracy: 0.5916.. 0.0604 s/batch
# Epoch: 2/10.. Loss: 0.0690.. Test accuracy: 0.5957.. 0.0578 s/batch
# Epoch: 2/10.. Loss: 0.0556.. Test accuracy: 0.5912.. 0.0638 s/batch
# Epoch: 2/10.. Loss: 0.0490.. Test accuracy: 0.5998.. 0.0631 s/batch
# Epoch: 2/10.. Loss: 0.0548.. Test accuracy: 0.6113.. 0.0585 s/batch
# Epoch: 2/10.. Loss: 0.0613.. Test accuracy: 0.5914.. 0.0579 s/batch
# Epoch: 2/10.. Loss: 0.0394.. Test accuracy: 0.5910.. 0.0660 s/batch
# Epoch: 2/10.. Loss: 0.0429.. Test accuracy: 0.5988.. 0.0675 s/batch
# Epoch: 2/10.. Loss: 0.0524.. Test accuracy: 0.5842.. 0.0674 s/batch
# Epoch: 2/10.. Loss: 0.0550.. Test accuracy: 0.6008.. 0.0663 s/batch
# Epoch: 2/10.. Loss: 0.0560.. Test accuracy: 0.6105.. 0.0632 s/batch
# Epoch: 2/10.. Loss: 0.0564.. Test accuracy: 0.6139.. 0.0650 s/batch
# Epoch: 2/10.. Loss: 0.0697.. Test accuracy: 0.5947.. 0.0606 s/batch
# Epoch: 2/10.. Loss: 0.0467.. Test accuracy: 0.6111.. 0.0640 s/batch
# Epoch: 2/10.. Loss: 0.0697.. Test accuracy: 0.5930.. 0.0630 s/batch
# Epoch: 2/10.. Loss: 0.0500.. Test accuracy: 0.5924.. 0.0665 s/batch
# Epoch: 2/10.. Loss: 0.0595.. Test accuracy: 0.5969.. 0.0587 s/batch
# Epoch: 2/10.. Loss: 0.0483.. Test accuracy: 0.6119.. 0.0590 s/batch
# Epoch: 2/10.. Loss: 0.0562.. Test accuracy: 0.6145.. 0.0651 s/batch
# Epoch: 2/10.. Loss: 0.0566.. Test accuracy: 0.6195.. 0.0592 s/batch
# Epoch: 2/10.. Loss: 0.0591.. Test accuracy: 0.6008.. 0.0559 s/batch
# Epoch: 2/10.. Loss: 0.0598.. Test accuracy: 0.5938.. 0.0572 s/batch
# Epoch: 2/10.. Loss: 0.0661.. Test accuracy: 0.5838.. 0.0620 s/batch
# Epoch: 2/10.. Loss: 0.0586.. Test accuracy: 0.5947.. 0.0654 s/batch
# Epoch: 3/10.. Loss: 0.0577.. Test accuracy: 0.6033.. 0.0582 s/batch
# Epoch: 3/10.. Loss: 0.0434.. Test accuracy: 0.6180.. 0.0667 s/batch
# Epoch: 3/10.. Loss: 0.0639.. Test accuracy: 0.6062.. 0.0630 s/batch
# Epoch: 3/10.. Loss: 0.0697.. Test accuracy: 0.6055.. 0.0618 s/batch
# Epoch: 3/10.. Loss: 0.0370.. Test accuracy: 0.6152.. 0.0584 s/batch
# Epoch: 3/10.. Loss: 0.0686.. Test accuracy: 0.6057.. 0.0745 s/batch
# Epoch: 3/10.. Loss: 0.0474.. Test accuracy: 0.6025.. 0.0624 s/batch
# Epoch: 3/10.. Loss: 0.0397.. Test accuracy: 0.6090.. 0.0584 s/batch
# Epoch: 3/10.. Loss: 0.0470.. Test accuracy: 0.6072.. 0.0570 s/batch
# Epoch: 3/10.. Loss: 0.0520.. Test accuracy: 0.6100.. 0.0637 s/batch
# Epoch: 3/10.. Loss: 0.0505.. Test accuracy: 0.6086.. 0.0598 s/batch
# Epoch: 3/10.. Loss: 0.0670.. Test accuracy: 0.6129.. 0.0584 s/batch
# Epoch: 3/10.. Loss: 0.0616.. Test accuracy: 0.6121.. 0.0585 s/batch
# Epoch: 3/10.. Loss: 0.0597.. Test accuracy: 0.6223.. 0.0809 s/batch
# Epoch: 3/10.. Loss: 0.0659.. Test accuracy: 0.6205.. 0.0648 s/batch
# Epoch: 3/10.. Loss: 0.0529.. Test accuracy: 0.6104.. 0.0861 s/batch
# Epoch: 3/10.. Loss: 0.0500.. Test accuracy: 0.6176.. 0.0622 s/batch
# Epoch: 3/10.. Loss: 0.0608.. Test accuracy: 0.6109.. 0.0576 s/batch
# Epoch: 3/10.. Loss: 0.0557.. Test accuracy: 0.6100.. 0.0667 s/batch
# Epoch: 3/10.. Loss: 0.0456.. Test accuracy: 0.6152.. 0.0645 s/batch
# Epoch: 3/10.. Loss: 0.0482.. Test accuracy: 0.6104.. 0.0601 s/batch
# Epoch: 3/10.. Loss: 0.0627.. Test accuracy: 0.6137.. 0.0614 s/batch
# Epoch: 3/10.. Loss: 0.0451.. Test accuracy: 0.6164.. 0.0653 s/batch
# Epoch: 3/10.. Loss: 0.0460.. Test accuracy: 0.6275.. 0.0606 s/batch
# Epoch: 3/10.. Loss: 0.0682.. Test accuracy: 0.6178.. 0.0620 s/batch
# Epoch: 3/10.. Loss: 0.0547.. Test accuracy: 0.6160.. 0.0588 s/batch
# Epoch: 3/10.. Loss: 0.0471.. Test accuracy: 0.6146.. 0.0627 s/batch
# Epoch: 3/10.. Loss: 0.0412.. Test accuracy: 0.6125.. 0.0633 s/batch
# Epoch: 3/10.. Loss: 0.0520.. Test accuracy: 0.6236.. 0.0678 s/batch
# Epoch: 3/10.. Loss: 0.0636.. Test accuracy: 0.6316.. 0.0601 s/batch
# Epoch: 3/10.. Loss: 0.0574.. Test accuracy: 0.6234.. 0.0583 s/batch
# Epoch: 3/10.. Loss: 0.0469.. Test accuracy: 0.6109.. 0.0651 s/batch
# Epoch: 3/10.. Loss: 0.0588.. Test accuracy: 0.6225.. 0.0621 s/batch
# Epoch: 3/10.. Loss: 0.0549.. Test accuracy: 0.6232.. 0.0616 s/batch
# Epoch: 3/10.. Loss: 0.0553.. Test accuracy: 0.6217.. 0.0590 s/batch
# Epoch: 3/10.. Loss: 0.0579.. Test accuracy: 0.6211.. 0.0567 s/batch
# Epoch: 3/10.. Loss: 0.0557.. Test accuracy: 0.6313.. 0.0579 s/batch
# Epoch: 3/10.. Loss: 0.0657.. Test accuracy: 0.6145.. 0.0692 s/batch
# Epoch: 4/10.. Loss: 0.0470.. Test accuracy: 0.6182.. 0.0321 s/batch
# Epoch: 4/10.. Loss: 0.0450.. Test accuracy: 0.6293.. 0.0677 s/batch
# Epoch: 4/10.. Loss: 0.0499.. Test accuracy: 0.6102.. 0.0589 s/batch
# Epoch: 4/10.. Loss: 0.0482.. Test accuracy: 0.6242.. 0.0605 s/batch
# Epoch: 4/10.. Loss: 0.0642.. Test accuracy: 0.6195.. 0.0645 s/batch
# Epoch: 4/10.. Loss: 0.0671.. Test accuracy: 0.6182.. 0.0554 s/batch
# Epoch: 4/10.. Loss: 0.0564.. Test accuracy: 0.6168.. 0.0566 s/batch
# Epoch: 4/10.. Loss: 0.0571.. Test accuracy: 0.6193.. 0.0617 s/batch
# Epoch: 4/10.. Loss: 0.0614.. Test accuracy: 0.6178.. 0.0606 s/batch
# Epoch: 4/10.. Loss: 0.0456.. Test accuracy: 0.6197.. 0.0631 s/batch
# Epoch: 4/10.. Loss: 0.0796.. Test accuracy: 0.6146.. 0.0607 s/batch
# Epoch: 4/10.. Loss: 0.0425.. Test accuracy: 0.6230.. 0.0653 s/batch
# Epoch: 4/10.. Loss: 0.0573.. Test accuracy: 0.6264.. 0.0594 s/batch
# Epoch: 4/10.. Loss: 0.0441.. Test accuracy: 0.6178.. 0.0603 s/batch
# Epoch: 4/10.. Loss: 0.0506.. Test accuracy: 0.6211.. 0.0596 s/batch
# Epoch: 4/10.. Loss: 0.0565.. Test accuracy: 0.6240.. 0.0631 s/batch
# Epoch: 4/10.. Loss: 0.0561.. Test accuracy: 0.6232.. 0.0644 s/batch
# Epoch: 4/10.. Loss: 0.0598.. Test accuracy: 0.6346.. 0.0590 s/batch
# Epoch: 4/10.. Loss: 0.0611.. Test accuracy: 0.6109.. 0.0653 s/batch
# Epoch: 4/10.. Loss: 0.0541.. Test accuracy: 0.6191.. 0.0649 s/batch
# Epoch: 4/10.. Loss: 0.0709.. Test accuracy: 0.6082.. 0.0622 s/batch
# Epoch: 4/10.. Loss: 0.0477.. Test accuracy: 0.6322.. 0.0629 s/batch
# Epoch: 4/10.. Loss: 0.0612.. Test accuracy: 0.6180.. 0.0615 s/batch
# Epoch: 4/10.. Loss: 0.0590.. Test accuracy: 0.6250.. 0.0591 s/batch
# Epoch: 4/10.. Loss: 0.0635.. Test accuracy: 0.6084.. 0.0655 s/batch
# Epoch: 4/10.. Loss: 0.0648.. Test accuracy: 0.6252.. 0.0636 s/batch
# Epoch: 4/10.. Loss: 0.0550.. Test accuracy: 0.6168.. 0.0586 s/batch
# Epoch: 4/10.. Loss: 0.0664.. Test accuracy: 0.6180.. 0.0840 s/batch
# Epoch: 4/10.. Loss: 0.0729.. Test accuracy: 0.6168.. 0.0657 s/batch
# Epoch: 4/10.. Loss: 0.0320.. Test accuracy: 0.6328.. 0.0645 s/batch
# Epoch: 4/10.. Loss: 0.0534.. Test accuracy: 0.6254.. 0.0618 s/batch
# Epoch: 4/10.. Loss: 0.0414.. Test accuracy: 0.6277.. 0.0598 s/batch
# Epoch: 4/10.. Loss: 0.0475.. Test accuracy: 0.6203.. 0.0580 s/batch
# Epoch: 4/10.. Loss: 0.0599.. Test accuracy: 0.6330.. 0.0598 s/batch
# Epoch: 4/10.. Loss: 0.0476.. Test accuracy: 0.6254.. 0.0632 s/batch
# Epoch: 4/10.. Loss: 0.0478.. Test accuracy: 0.6256.. 0.0665 s/batch
# Epoch: 4/10.. Loss: 0.0426.. Test accuracy: 0.6266.. 0.0592 s/batch
# Epoch: 4/10.. Loss: 0.0609.. Test accuracy: 0.6193.. 0.0587 s/batch
# Epoch: 4/10.. Loss: 0.0553.. Test accuracy: 0.6221.. 0.0589 s/batch
# Epoch: 5/10.. Loss: 0.0480.. Test accuracy: 0.6225.. 0.0818 s/batch
# Epoch: 5/10.. Loss: 0.0578.. Test accuracy: 0.6146.. 0.0625 s/batch
# Epoch: 5/10.. Loss: 0.0494.. Test accuracy: 0.6268.. 0.0648 s/batch
# Epoch: 5/10.. Loss: 0.0608.. Test accuracy: 0.6244.. 0.0633 s/batch
# Epoch: 5/10.. Loss: 0.0500.. Test accuracy: 0.6338.. 0.0636 s/batch
# Epoch: 5/10.. Loss: 0.0568.. Test accuracy: 0.6271.. 0.0639 s/batch
# Epoch: 5/10.. Loss: 0.0463.. Test accuracy: 0.6225.. 0.0650 s/batch
# Epoch: 5/10.. Loss: 0.0442.. Test accuracy: 0.6332.. 0.0616 s/batch
# Epoch: 5/10.. Loss: 0.0456.. Test accuracy: 0.6299.. 0.0618 s/batch
# Epoch: 5/10.. Loss: 0.0368.. Test accuracy: 0.6234.. 0.0619 s/batch
# Epoch: 5/10.. Loss: 0.0619.. Test accuracy: 0.6330.. 0.0630 s/batch
# Epoch: 5/10.. Loss: 0.0433.. Test accuracy: 0.6213.. 0.0570 s/batch
# Epoch: 5/10.. Loss: 0.0482.. Test accuracy: 0.6221.. 0.0566 s/batch
# Epoch: 5/10.. Loss: 0.0568.. Test accuracy: 0.6207.. 0.0575 s/batch
# Epoch: 5/10.. Loss: 0.0416.. Test accuracy: 0.6240.. 0.0566 s/batch
# Epoch: 5/10.. Loss: 0.0626.. Test accuracy: 0.6254.. 0.0652 s/batch
# Epoch: 5/10.. Loss: 0.0512.. Test accuracy: 0.6187.. 0.0579 s/batch
# Epoch: 5/10.. Loss: 0.0542.. Test accuracy: 0.6234.. 0.0632 s/batch
# Epoch: 5/10.. Loss: 0.0740.. Test accuracy: 0.6191.. 0.0605 s/batch
# Epoch: 5/10.. Loss: 0.0485.. Test accuracy: 0.6174.. 0.0578 s/batch
# Epoch: 5/10.. Loss: 0.0452.. Test accuracy: 0.6176.. 0.0606 s/batch
# Epoch: 5/10.. Loss: 0.0480.. Test accuracy: 0.6191.. 0.0634 s/batch
# Epoch: 5/10.. Loss: 0.0511.. Test accuracy: 0.6172.. 0.0607 s/batch
# Epoch: 5/10.. Loss: 0.0496.. Test accuracy: 0.6221.. 0.0630 s/batch
# Epoch: 5/10.. Loss: 0.0540.. Test accuracy: 0.6236.. 0.0579 s/batch
# Epoch: 5/10.. Loss: 0.0648.. Test accuracy: 0.6129.. 0.0627 s/batch
# Epoch: 5/10.. Loss: 0.0576.. Test accuracy: 0.6221.. 0.0626 s/batch
# Epoch: 5/10.. Loss: 0.0609.. Test accuracy: 0.6293.. 0.0650 s/batch
# Epoch: 5/10.. Loss: 0.0589.. Test accuracy: 0.6230.. 0.0620 s/batch
# Epoch: 5/10.. Loss: 0.0565.. Test accuracy: 0.6246.. 0.0623 s/batch
# Epoch: 5/10.. Loss: 0.0610.. Test accuracy: 0.6082.. 0.0614 s/batch
# Epoch: 5/10.. Loss: 0.0526.. Test accuracy: 0.6187.. 0.0653 s/batch
# Epoch: 5/10.. Loss: 0.0663.. Test accuracy: 0.6217.. 0.0639 s/batch
# Epoch: 5/10.. Loss: 0.0579.. Test accuracy: 0.6238.. 0.0663 s/batch
# Epoch: 5/10.. Loss: 0.0551.. Test accuracy: 0.6326.. 0.0654 s/batch
# Epoch: 5/10.. Loss: 0.0515.. Test accuracy: 0.6248.. 0.0555 s/batch
# Epoch: 5/10.. Loss: 0.0515.. Test accuracy: 0.6260.. 0.0630 s/batch
# Epoch: 5/10.. Loss: 0.0340.. Test accuracy: 0.6385.. 0.0556 s/batch
# Epoch: 6/10.. Loss: 0.0383.. Test accuracy: 0.6221.. 0.0540 s/batch
# Epoch: 6/10.. Loss: 0.0474.. Test accuracy: 0.6211.. 0.0618 s/batch
# Epoch: 6/10.. Loss: 0.0602.. Test accuracy: 0.6207.. 0.0603 s/batch
# Epoch: 6/10.. Loss: 0.0480.. Test accuracy: 0.6207.. 0.0603 s/batch
# Epoch: 6/10.. Loss: 0.0506.. Test accuracy: 0.6287.. 0.0679 s/batch
# Epoch: 6/10.. Loss: 0.0557.. Test accuracy: 0.6334.. 0.0650 s/batch
# Epoch: 6/10.. Loss: 0.0646.. Test accuracy: 0.6205.. 0.0597 s/batch
# Epoch: 6/10.. Loss: 0.0536.. Test accuracy: 0.6141.. 0.0637 s/batch
# Epoch: 6/10.. Loss: 0.0419.. Test accuracy: 0.6260.. 0.0638 s/batch
# Epoch: 6/10.. Loss: 0.0345.. Test accuracy: 0.6266.. 0.0611 s/batch
# Epoch: 6/10.. Loss: 0.0574.. Test accuracy: 0.6184.. 0.0657 s/batch
# Epoch: 6/10.. Loss: 0.0788.. Test accuracy: 0.6145.. 0.0598 s/batch
# Epoch: 6/10.. Loss: 0.0460.. Test accuracy: 0.6232.. 0.0593 s/batch
# Epoch: 6/10.. Loss: 0.0489.. Test accuracy: 0.6203.. 0.0643 s/batch
# Epoch: 6/10.. Loss: 0.0573.. Test accuracy: 0.6201.. 0.0664 s/batch
# Epoch: 6/10.. Loss: 0.0526.. Test accuracy: 0.6221.. 0.0631 s/batch
# Epoch: 6/10.. Loss: 0.0643.. Test accuracy: 0.6230.. 0.0647 s/batch
# Epoch: 6/10.. Loss: 0.0664.. Test accuracy: 0.6135.. 0.0627 s/batch
# Epoch: 6/10.. Loss: 0.0378.. Test accuracy: 0.6156.. 0.0575 s/batch
# Epoch: 6/10.. Loss: 0.0510.. Test accuracy: 0.6271.. 0.0678 s/batch
# Epoch: 6/10.. Loss: 0.0600.. Test accuracy: 0.6225.. 0.0623 s/batch
# Epoch: 6/10.. Loss: 0.0687.. Test accuracy: 0.6199.. 0.0591 s/batch
# Epoch: 6/10.. Loss: 0.0542.. Test accuracy: 0.6152.. 0.0646 s/batch
# Epoch: 6/10.. Loss: 0.0487.. Test accuracy: 0.6133.. 0.0614 s/batch
# Epoch: 6/10.. Loss: 0.0566.. Test accuracy: 0.6115.. 0.0597 s/batch
# Epoch: 6/10.. Loss: 0.0529.. Test accuracy: 0.6123.. 0.0632 s/batch
# Epoch: 6/10.. Loss: 0.0601.. Test accuracy: 0.6195.. 0.0609 s/batch
# Epoch: 6/10.. Loss: 0.0502.. Test accuracy: 0.6309.. 0.0606 s/batch
# Epoch: 6/10.. Loss: 0.0393.. Test accuracy: 0.6270.. 0.0662 s/batch
# Epoch: 6/10.. Loss: 0.0560.. Test accuracy: 0.6215.. 0.0665 s/batch
# Epoch: 6/10.. Loss: 0.0420.. Test accuracy: 0.6275.. 0.0652 s/batch
# Epoch: 6/10.. Loss: 0.0649.. Test accuracy: 0.6303.. 0.0672 s/batch
# Epoch: 6/10.. Loss: 0.0485.. Test accuracy: 0.6260.. 0.0663 s/batch
# Epoch: 6/10.. Loss: 0.0568.. Test accuracy: 0.6180.. 0.0610 s/batch
# Epoch: 6/10.. Loss: 0.0380.. Test accuracy: 0.6283.. 0.0633 s/batch
# Epoch: 6/10.. Loss: 0.0553.. Test accuracy: 0.6182.. 0.0607 s/batch
# Epoch: 6/10.. Loss: 0.0692.. Test accuracy: 0.6227.. 0.0632 s/batch
# Epoch: 6/10.. Loss: 0.0811.. Test accuracy: 0.6186.. 0.0573 s/batch
# Epoch: 7/10.. Loss: 0.0591.. Test accuracy: 0.6229.. 0.0456 s/batch
# Epoch: 7/10.. Loss: 0.0541.. Test accuracy: 0.6379.. 0.0661 s/batch
# Epoch: 7/10.. Loss: 0.0496.. Test accuracy: 0.6227.. 0.0645 s/batch
# Epoch: 7/10.. Loss: 0.0506.. Test accuracy: 0.6291.. 0.0615 s/batch
# Epoch: 7/10.. Loss: 0.0548.. Test accuracy: 0.6164.. 0.0649 s/batch
# Epoch: 7/10.. Loss: 0.0494.. Test accuracy: 0.6209.. 0.0622 s/batch
# Epoch: 7/10.. Loss: 0.0588.. Test accuracy: 0.6281.. 0.0596 s/batch
# Epoch: 7/10.. Loss: 0.0524.. Test accuracy: 0.6254.. 0.0585 s/batch
# Epoch: 7/10.. Loss: 0.0443.. Test accuracy: 0.6207.. 0.0646 s/batch
# Epoch: 7/10.. Loss: 0.0585.. Test accuracy: 0.6250.. 0.0649 s/batch
# Epoch: 7/10.. Loss: 0.0599.. Test accuracy: 0.6236.. 0.0647 s/batch
# Epoch: 7/10.. Loss: 0.0483.. Test accuracy: 0.6234.. 0.0637 s/batch
# Epoch: 7/10.. Loss: 0.0552.. Test accuracy: 0.6129.. 0.0649 s/batch
# Epoch: 7/10.. Loss: 0.0594.. Test accuracy: 0.6293.. 0.0591 s/batch
# Epoch: 7/10.. Loss: 0.0537.. Test accuracy: 0.6201.. 0.0597 s/batch
# Epoch: 7/10.. Loss: 0.0530.. Test accuracy: 0.6254.. 0.0614 s/batch
# Epoch: 7/10.. Loss: 0.0513.. Test accuracy: 0.6316.. 0.0575 s/batch
# Epoch: 7/10.. Loss: 0.0446.. Test accuracy: 0.6256.. 0.0660 s/batch
# Epoch: 7/10.. Loss: 0.0570.. Test accuracy: 0.6219.. 0.0648 s/batch
# Epoch: 7/10.. Loss: 0.0490.. Test accuracy: 0.6248.. 0.0596 s/batch
# Epoch: 7/10.. Loss: 0.0692.. Test accuracy: 0.6223.. 0.0640 s/batch
# Epoch: 7/10.. Loss: 0.0475.. Test accuracy: 0.6303.. 0.0642 s/batch
# Epoch: 7/10.. Loss: 0.0598.. Test accuracy: 0.6262.. 0.0608 s/batch
# Epoch: 7/10.. Loss: 0.0591.. Test accuracy: 0.6273.. 0.0613 s/batch
# Epoch: 7/10.. Loss: 0.0566.. Test accuracy: 0.6336.. 0.0636 s/batch
# Epoch: 7/10.. Loss: 0.0546.. Test accuracy: 0.6152.. 0.0635 s/batch
# Epoch: 7/10.. Loss: 0.0503.. Test accuracy: 0.6297.. 0.0628 s/batch
# Epoch: 7/10.. Loss: 0.0407.. Test accuracy: 0.6363.. 0.0656 s/batch
# Epoch: 7/10.. Loss: 0.0507.. Test accuracy: 0.6230.. 0.0653 s/batch
# Epoch: 7/10.. Loss: 0.0496.. Test accuracy: 0.6285.. 0.0609 s/batch
# Epoch: 7/10.. Loss: 0.0701.. Test accuracy: 0.6221.. 0.0579 s/batch
# Epoch: 7/10.. Loss: 0.0609.. Test accuracy: 0.6223.. 0.0632 s/batch
# Epoch: 7/10.. Loss: 0.0522.. Test accuracy: 0.6295.. 0.0633 s/batch
# Epoch: 7/10.. Loss: 0.0467.. Test accuracy: 0.6225.. 0.0604 s/batch
# Epoch: 7/10.. Loss: 0.0590.. Test accuracy: 0.6262.. 0.0645 s/batch
# Epoch: 7/10.. Loss: 0.0634.. Test accuracy: 0.6246.. 0.0663 s/batch
# Epoch: 7/10.. Loss: 0.0534.. Test accuracy: 0.6289.. 0.0621 s/batch
# Epoch: 7/10.. Loss: 0.0521.. Test accuracy: 0.6346.. 0.0612 s/batch
# Epoch: 7/10.. Loss: 0.0545.. Test accuracy: 0.6223.. 0.0570 s/batch
# Epoch: 8/10.. Loss: 0.0488.. Test accuracy: 0.6225.. 0.0900 s/batch
# Epoch: 8/10.. Loss: 0.0640.. Test accuracy: 0.6254.. 0.0620 s/batch
# Epoch: 8/10.. Loss: 0.0549.. Test accuracy: 0.6289.. 0.0572 s/batch
# Epoch: 8/10.. Loss: 0.0464.. Test accuracy: 0.6234.. 0.0643 s/batch
# Epoch: 8/10.. Loss: 0.0451.. Test accuracy: 0.6289.. 0.0588 s/batch
# Epoch: 8/10.. Loss: 0.0423.. Test accuracy: 0.6369.. 0.0658 s/batch
# Epoch: 8/10.. Loss: 0.0473.. Test accuracy: 0.6369.. 0.0651 s/batch
# Epoch: 8/10.. Loss: 0.0587.. Test accuracy: 0.6191.. 0.0657 s/batch
# Epoch: 8/10.. Loss: 0.0458.. Test accuracy: 0.6281.. 0.0638 s/batch
# Epoch: 8/10.. Loss: 0.0563.. Test accuracy: 0.6281.. 0.0615 s/batch
# Epoch: 8/10.. Loss: 0.0504.. Test accuracy: 0.6273.. 0.0628 s/batch
# Epoch: 8/10.. Loss: 0.0647.. Test accuracy: 0.6184.. 0.0647 s/batch
# Epoch: 8/10.. Loss: 0.0467.. Test accuracy: 0.6232.. 0.0602 s/batch
# Epoch: 8/10.. Loss: 0.0410.. Test accuracy: 0.6313.. 0.0639 s/batch
# Epoch: 8/10.. Loss: 0.0542.. Test accuracy: 0.6178.. 0.0633 s/batch
# Epoch: 8/10.. Loss: 0.0367.. Test accuracy: 0.6301.. 0.0637 s/batch
# Epoch: 8/10.. Loss: 0.0483.. Test accuracy: 0.6322.. 0.0635 s/batch
# Epoch: 8/10.. Loss: 0.0602.. Test accuracy: 0.6293.. 0.0600 s/batch
# Epoch: 8/10.. Loss: 0.0493.. Test accuracy: 0.6342.. 0.0577 s/batch
# Epoch: 8/10.. Loss: 0.0630.. Test accuracy: 0.6238.. 0.0578 s/batch
# Epoch: 8/10.. Loss: 0.0566.. Test accuracy: 0.6307.. 0.0589 s/batch
# Epoch: 8/10.. Loss: 0.0357.. Test accuracy: 0.6285.. 0.0596 s/batch
# Epoch: 8/10.. Loss: 0.0555.. Test accuracy: 0.6242.. 0.0634 s/batch
# Epoch: 8/10.. Loss: 0.0549.. Test accuracy: 0.6238.. 0.0597 s/batch
# Epoch: 8/10.. Loss: 0.0487.. Test accuracy: 0.6234.. 0.0662 s/batch
# Epoch: 8/10.. Loss: 0.0537.. Test accuracy: 0.6273.. 0.0609 s/batch
# Epoch: 8/10.. Loss: 0.0423.. Test accuracy: 0.6262.. 0.0567 s/batch
# Epoch: 8/10.. Loss: 0.0526.. Test accuracy: 0.6268.. 0.0635 s/batch
# Epoch: 8/10.. Loss: 0.0465.. Test accuracy: 0.6277.. 0.0632 s/batch
# Epoch: 8/10.. Loss: 0.0532.. Test accuracy: 0.6229.. 0.0559 s/batch
# Epoch: 8/10.. Loss: 0.0532.. Test accuracy: 0.6199.. 0.0568 s/batch
# Epoch: 8/10.. Loss: 0.0592.. Test accuracy: 0.6254.. 0.0601 s/batch
# Epoch: 8/10.. Loss: 0.0629.. Test accuracy: 0.6246.. 0.0588 s/batch
# Epoch: 8/10.. Loss: 0.0511.. Test accuracy: 0.6287.. 0.0640 s/batch
# Epoch: 8/10.. Loss: 0.0523.. Test accuracy: 0.6209.. 0.0632 s/batch
# Epoch: 8/10.. Loss: 0.0366.. Test accuracy: 0.6313.. 0.0661 s/batch
# Epoch: 8/10.. Loss: 0.0704.. Test accuracy: 0.6150.. 0.0643 s/batch
# Epoch: 8/10.. Loss: 0.0502.. Test accuracy: 0.6297.. 0.0586 s/batch
# Epoch: 9/10.. Loss: 0.0690.. Test accuracy: 0.6164.. 0.0587 s/batch
# Epoch: 9/10.. Loss: 0.0745.. Test accuracy: 0.6205.. 0.0642 s/batch
# Epoch: 9/10.. Loss: 0.0467.. Test accuracy: 0.6197.. 0.0619 s/batch
# Epoch: 9/10.. Loss: 0.0577.. Test accuracy: 0.6098.. 0.0643 s/batch
# Epoch: 9/10.. Loss: 0.0669.. Test accuracy: 0.6232.. 0.0657 s/batch
# Epoch: 9/10.. Loss: 0.0651.. Test accuracy: 0.6187.. 0.0660 s/batch
# Epoch: 9/10.. Loss: 0.0578.. Test accuracy: 0.6158.. 0.0654 s/batch
# Epoch: 9/10.. Loss: 0.0465.. Test accuracy: 0.6271.. 0.0590 s/batch
# Epoch: 9/10.. Loss: 0.0551.. Test accuracy: 0.6176.. 0.0600 s/batch
# Epoch: 9/10.. Loss: 0.0644.. Test accuracy: 0.6176.. 0.0620 s/batch
# Epoch: 9/10.. Loss: 0.0539.. Test accuracy: 0.6174.. 0.0648 s/batch
# Epoch: 9/10.. Loss: 0.0412.. Test accuracy: 0.6271.. 0.0660 s/batch
# Epoch: 9/10.. Loss: 0.0523.. Test accuracy: 0.6193.. 0.0632 s/batch
# Epoch: 9/10.. Loss: 0.0367.. Test accuracy: 0.6295.. 0.0669 s/batch
# Epoch: 9/10.. Loss: 0.0666.. Test accuracy: 0.6242.. 0.0637 s/batch
# Epoch: 9/10.. Loss: 0.0697.. Test accuracy: 0.6113.. 0.0612 s/batch
# Epoch: 9/10.. Loss: 0.0674.. Test accuracy: 0.6229.. 0.0620 s/batch
# Epoch: 9/10.. Loss: 0.0448.. Test accuracy: 0.6137.. 0.0620 s/batch
# Epoch: 9/10.. Loss: 0.0481.. Test accuracy: 0.6201.. 0.0610 s/batch
# Epoch: 9/10.. Loss: 0.0517.. Test accuracy: 0.6240.. 0.0587 s/batch
# Epoch: 9/10.. Loss: 0.0469.. Test accuracy: 0.6309.. 0.0600 s/batch
# Epoch: 9/10.. Loss: 0.0621.. Test accuracy: 0.6217.. 0.0671 s/batch
# Epoch: 9/10.. Loss: 0.0498.. Test accuracy: 0.6133.. 0.0645 s/batch
# Epoch: 9/10.. Loss: 0.0489.. Test accuracy: 0.6197.. 0.0599 s/batch
# Epoch: 9/10.. Loss: 0.0591.. Test accuracy: 0.6168.. 0.0623 s/batch
# Epoch: 9/10.. Loss: 0.0574.. Test accuracy: 0.6213.. 0.0615 s/batch
# Epoch: 9/10.. Loss: 0.0583.. Test accuracy: 0.6238.. 0.0575 s/batch
# Epoch: 9/10.. Loss: 0.0456.. Test accuracy: 0.6186.. 0.0641 s/batch
# Epoch: 9/10.. Loss: 0.0714.. Test accuracy: 0.6199.. 0.0589 s/batch
# Epoch: 9/10.. Loss: 0.0711.. Test accuracy: 0.6207.. 0.0645 s/batch
# Epoch: 9/10.. Loss: 0.0388.. Test accuracy: 0.6281.. 0.0604 s/batch
# Epoch: 9/10.. Loss: 0.0501.. Test accuracy: 0.6139.. 0.0642 s/batch
# Epoch: 9/10.. Loss: 0.0619.. Test accuracy: 0.6127.. 0.0636 s/batch
# Epoch: 9/10.. Loss: 0.0601.. Test accuracy: 0.6205.. 0.0658 s/batch
# Epoch: 9/10.. Loss: 0.0537.. Test accuracy: 0.6264.. 0.0606 s/batch
# Epoch: 9/10.. Loss: 0.0463.. Test accuracy: 0.6152.. 0.0649 s/batch
# Epoch: 9/10.. Loss: 0.0355.. Test accuracy: 0.6246.. 0.0635 s/batch
# Epoch: 9/10.. Loss: 0.0758.. Test accuracy: 0.6184.. 0.0642 s/batch
# Epoch: 10/10.. Loss: 0.0463.. Test accuracy: 0.6318.. 0.0520 s/batch
# Epoch: 10/10.. Loss: 0.0482.. Test accuracy: 0.6221.. 0.0642 s/batch
# Epoch: 10/10.. Loss: 0.0496.. Test accuracy: 0.6240.. 0.0649 s/batch
# Epoch: 10/10.. Loss: 0.0719.. Test accuracy: 0.6205.. 0.0606 s/batch
# Epoch: 10/10.. Loss: 0.0555.. Test accuracy: 0.6240.. 0.0642 s/batch
# Epoch: 10/10.. Loss: 0.0572.. Test accuracy: 0.6209.. 0.0621 s/batch
# Epoch: 10/10.. Loss: 0.0458.. Test accuracy: 0.6232.. 0.0616 s/batch
# Epoch: 10/10.. Loss: 0.0510.. Test accuracy: 0.6262.. 0.0569 s/batch
# Epoch: 10/10.. Loss: 0.0653.. Test accuracy: 0.6201.. 0.0613 s/batch
# Epoch: 10/10.. Loss: 0.0532.. Test accuracy: 0.6252.. 0.0645 s/batch
# Epoch: 10/10.. Loss: 0.0602.. Test accuracy: 0.6250.. 0.0599 s/batch
# Epoch: 10/10.. Loss: 0.0517.. Test accuracy: 0.6293.. 0.0650 s/batch
# Epoch: 10/10.. Loss: 0.0613.. Test accuracy: 0.6355.. 0.0616 s/batch
# Epoch: 10/10.. Loss: 0.0445.. Test accuracy: 0.6313.. 0.0637 s/batch
# Epoch: 10/10.. Loss: 0.0527.. Test accuracy: 0.6215.. 0.0614 s/batch
# Epoch: 10/10.. Loss: 0.0559.. Test accuracy: 0.6264.. 0.0570 s/batch
# Epoch: 10/10.. Loss: 0.0506.. Test accuracy: 0.6256.. 0.0558 s/batch
# Epoch: 10/10.. Loss: 0.0474.. Test accuracy: 0.6131.. 0.0569 s/batch
# Epoch: 10/10.. Loss: 0.0548.. Test accuracy: 0.6189.. 0.0589 s/batch
# Epoch: 10/10.. Loss: 0.0678.. Test accuracy: 0.6170.. 0.0649 s/batch
# Epoch: 10/10.. Loss: 0.0549.. Test accuracy: 0.6330.. 0.0610 s/batch
# Epoch: 10/10.. Loss: 0.0509.. Test accuracy: 0.6307.. 0.0645 s/batch
# Epoch: 10/10.. Loss: 0.0529.. Test accuracy: 0.6232.. 0.0649 s/batch
# Epoch: 10/10.. Loss: 0.0369.. Test accuracy: 0.6275.. 0.0583 s/batch
# Epoch: 10/10.. Loss: 0.0630.. Test accuracy: 0.6223.. 0.0633 s/batch
# Epoch: 10/10.. Loss: 0.0586.. Test accuracy: 0.6213.. 0.0572 s/batch
# Epoch: 10/10.. Loss: 0.0568.. Test accuracy: 0.6213.. 0.0599 s/batch
# Epoch: 10/10.. Loss: 0.0377.. Test accuracy: 0.6342.. 0.0591 s/batch
# Epoch: 10/10.. Loss: 0.0531.. Test accuracy: 0.6240.. 0.0656 s/batch
# Epoch: 10/10.. Loss: 0.0504.. Test accuracy: 0.6209.. 0.0647 s/batch
# Epoch: 10/10.. Loss: 0.0464.. Test accuracy: 0.6371.. 0.0589 s/batch
# Epoch: 10/10.. Loss: 0.0504.. Test accuracy: 0.6336.. 0.0653 s/batch
# Epoch: 10/10.. Loss: 0.0453.. Test accuracy: 0.6242.. 0.0624 s/batch
# Epoch: 10/10.. Loss: 0.0428.. Test accuracy: 0.6283.. 0.0621 s/batch
# Epoch: 10/10.. Loss: 0.0495.. Test accuracy: 0.6125.. 0.0757 s/batch
# Epoch: 10/10.. Loss: 0.0611.. Test accuracy: 0.6244.. 0.0565 s/batch
# Epoch: 10/10.. Loss: 0.0506.. Test accuracy: 0.6266.. 0.0654 s/batch
# Epoch: 10/10.. Loss: 0.0396.. Test accuracy: 0.6225.. 0.0585 s/batch
# Epoch: 10/10.. Loss: 0.0655.. Test accuracy: 0.6291.. 0.0631 s/batch

# %% [markdown]
# Save best trained model.

# %%
torch.save(net.state_dict(), 'drive/MyDrive/Colab Notebooks/CNN_pytorch.ckpt')
